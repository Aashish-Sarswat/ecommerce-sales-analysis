# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ecommerce_sales_beginner.csv')
df
# Out:
#      Order_ID  Order_Date     Product     Category  Quantity    Price  \
# 0        1001  2025-06-29       Shoes      Fashion         1   3500.0
# 1        1002  2025-01-21       Mouse  Accessories         3    900.0
# 2        1003  2025-03-16       Shoes      Fashion         3   3500.0
# 3        1004  2025-06-01    Backpack      Fashion         3   2200.0
# 4        1005  2025-06-07    Backpack      Fashion         2   2200.0
# ..        ...         ...         ...          ...       ...      ...
# 147      1148  2025-05-16  Headphones  Electronics         4   2500.0
# 148      1149  2025-05-25     Monitor  Electronics         3  12000.0
# 149      1150  2025-02-05    Keyboard  Accessories         2   1800.0
# 150      1011  2025-05-15  Headphones  Electronics         1   2500.0
# 151      1056  2025-05-27       Shoes      Fashion         4   3500.0
#
#           City Payment_Method
# 0       Mumbai           Cash
# 1        Delhi     Debit Card
# 2         Pune           Cash
# 3         Pune    Credit Card
# 4        Delhi           Cash
# ..         ...            ...
# 147       Pune            UPI
# 148     Indore            UPI
# 149  Bengaluru     Debit Card
# 150     Indore     Debit Card
# 151  Bengaluru            UPI
#
# [152 rows x 8 columns]

# %%
df.head()
# Out:
#    Order_ID  Order_Date   Product     Category  Quantity   Price    City  \
# 0      1001  2025-06-29     Shoes      Fashion         1  3500.0  Mumbai
# 1      1002  2025-01-21     Mouse  Accessories         3   900.0   Delhi
# 2      1003  2025-03-16     Shoes      Fashion         3  3500.0    Pune
# 3      1004  2025-06-01  Backpack      Fashion         3  2200.0    Pune
# 4      1005  2025-06-07  Backpack      Fashion         2  2200.0   Delhi
#
#   Payment_Method
# 0           Cash
# 1     Debit Card
# 2           Cash
# 3    Credit Card
# 4           Cash

# %%
df.shape
# Out:
# (152, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        152 non-null    int64
#  1   Order_Date      152 non-null    str
#  2   Product         152 non-null    str
#  3   Category        152 non-null    str
#  4   Quantity        152 non-null    int64
#  5   Price           151 non-null    float64
#  6   City            151 non-null    str
#  7   Payment_Method  151 non-null    str
# dtypes: float64(1), int64(2), str(5)
# memory usage: 15.5 KB

# %%
df.describe()
# Out:
#           Order_ID    Quantity         Price
# count   152.000000  152.000000    151.000000
# mean   1074.947368    2.493421  11138.410596
# std      43.500139    1.103857  17293.724723
# min    1001.000000    1.000000    900.000000
# 25%    1037.750000    2.000000   1800.000000
# 50%    1074.500000    2.500000   2500.000000
# 75%    1112.250000    3.000000  12000.000000
# max    1150.000000    4.000000  55000.000000

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Product           0
# Category          0
# Quantity          0
# Price             1
# City              1
# Payment_Method    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df[df.duplicated()]
# Out:
#      Order_ID  Order_Date     Product     Category  Quantity   Price  \
# 150      1011  2025-05-15  Headphones  Electronics         1  2500.0
# 151      1056  2025-05-27       Shoes      Fashion         4  3500.0
#
#           City Payment_Method
# 150     Indore     Debit Card
# 151  Bengaluru            UPI

# %%
df =df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (150, 8)

# %%
df[df['Price'].isnull()]
# Out:
#     Order_ID  Order_Date Product     Category  Quantity  Price    City  \
# 40      1041  2025-01-27  Laptop  Electronics         2    NaN  Indore
#
#    Payment_Method
# 40           Cash

# %%
df[df['City'].isnull()]
# Out:
#    Order_ID  Order_Date Product Category  Quantity   Price City Payment_Method
# 7      1008  2025-06-19   Shoes  Fashion         4  3500.0  NaN           Cash

# %%
df[df['Payment_Method'].isnull()]
# Out:
#     Order_ID  Order_Date   Product Category  Quantity   Price    City  \
# 25      1026  2025-06-12  Backpack  Fashion         3  2200.0  Indore
#
#    Payment_Method
# 25            NaN

# %%
df['Order_Date'].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df['Order_Date'].dtype
# Out:
# dtype('<M8[us]')

# %%
df[df['Product']=='Laptop']
# Out:
#      Order_ID Order_Date Product     Category  Quantity    Price       City  \
# 15       1016 2025-06-13  Laptop  Electronics         2  55000.0  Bengaluru
# 23       1024 2025-03-29  Laptop  Electronics         1  55000.0  Bengaluru
# 29       1030 2025-04-11  Laptop  Electronics         3  55000.0     Mumbai
# 40       1041 2025-01-27  Laptop  Electronics         2      NaN     Indore
# 45       1046 2025-03-03  Laptop  Electronics         1  55000.0      Delhi
# 48       1049 2025-01-02  Laptop  Electronics         2  55000.0  Bengaluru
# 56       1057 2025-06-17  Laptop  Electronics         4  55000.0      Delhi
# 57       1058 2025-01-11  Laptop  Electronics         4  55000.0     Indore
# 69       1070 2025-05-22  Laptop  Electronics         1  55000.0  Bengaluru
# 80       1081 2025-04-26  Laptop  Electronics         3  55000.0       Pune
# 86       1087 2025-05-17  Laptop  Electronics         3  55000.0       Pune
# 89       1090 2025-02-05  Laptop  Electronics         1  55000.0  Bengaluru
# 96       1097 2025-01-08  Laptop  Electronics         1  55000.0  Bengaluru
# 120      1121 2025-06-10  Laptop  Electronics         1  55000.0     Mumbai
# 131      1132 2025-04-06  Laptop  Electronics         4  55000.0       Pune
# 132      1133 2025-01-13  Laptop  Electronics         3  55000.0     Indore
# 133      1134 2025-01-30  Laptop  Electronics         1  55000.0     Indore
# 136      1137 2025-05-27  Laptop  Electronics         4  55000.0     Indore
#
#     Payment_Method
# 15     Credit Card
# 23            Cash
# 29             UPI
# 40            Cash
# 45            Cash
# 48     Credit Card
# 56            Cash
# 57             UPI
# 69            Cash
# 80             UPI
# 86     Credit Card
# 89             UPI
# 96            Cash
# 120     Debit Card
# 131           Cash
# 132     Debit Card
# 133    Credit Card
# 136     Debit Card

# %%
laptop_price  = df.loc[df['Product']=='Laptop','Price'].median()
df['Price'] = df['Price'].fillna(laptop_price)

# %%
df['Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
df['City'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Payment_Method'] = df['Payment_Method'].fillna('Unknown')

# %%
df['Payment_Method'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Product           0
# Category          0
# Quantity          0
# Price             0
# City              0
# Payment_Method    0
# dtype: int64

# %%
df['Sales'] =df['Quantity']*df['Price']

# %%
df.head()
# Out:
#    Order_ID Order_Date   Product     Category  Quantity   Price    City  \
# 0      1001 2025-06-29     Shoes      Fashion         1  3500.0  Mumbai
# 1      1002 2025-01-21     Mouse  Accessories         3   900.0   Delhi
# 2      1003 2025-03-16     Shoes      Fashion         3  3500.0    Pune
# 3      1004 2025-06-01  Backpack      Fashion         3  2200.0    Pune
# 4      1005 2025-06-07  Backpack      Fashion         2  2200.0   Delhi
#
#   Payment_Method    Sales
# 0           Cash   3500.0
# 1     Debit Card   2700.0
# 2           Cash  10500.0
# 3    Credit Card   6600.0
# 4           Cash   4400.0

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ## Question -1: Total Sales Kitni hui?

# %%
Total_Sales = df['Sales'].sum()
Total_Sales
# Out:
# np.float64(3907000.0)

# %% [markdown]
# ## Question -2 Average Order Value

# %%
# ek order per average customer kitna spend karta hai
Avg_Order =df['Sales'].mean()
Avg_Order
# Out:
# np.float64(26046.666666666668)

# %% [markdown]
# ## Question -3 Total Quantity Sold

# %%
#kitne product total sell hue ?
total_product_sell =df['Quantity'].sum()
total_product_sell
# Out:
# np.int64(374)

# %% [markdown]
# ## Question -4 Kaunsi Category Sabse Zyada Sales generate Karti hai ?

# %%
# here we use groupby() function
df.groupby('Category')["Sales"].sum()
# Out:
# Category
# Accessories     154800.0
# Electronics    3399500.0
# Fashion         352700.0
# Name: Sales, dtype: float64

# %%
df.groupby('Category')["Sales"].sum().sort_values(ascending = False)
# Out:
# Category
# Electronics    3399500.0
# Fashion         352700.0
# Accessories     154800.0
# Name: Sales, dtype: float64

# %% [markdown]
# ##  Question -5 Top Products

# %%
#konse Product sabse jyada revenue generate kar rahe hai
df.groupby('Product')["Sales"].sum().sort_values(ascending = False)
# Out:
# Product
# Laptop        2255000.0
# Phone          570000.0
# Monitor        492000.0
# Shoes          185500.0
# Backpack       167200.0
# Keyboard       109800.0
# Headphones      82500.0
# Mouse           45000.0
# Name: Sales, dtype: float64

# %% [markdown]
# ## Question -6 Which City generates the most Sales

# %%
df.groupby('City')["Sales"].sum().sort_values(ascending = False)
# Out:
# City
# Indore       1115300.0
# Pune          798000.0
# Bengaluru     764800.0
# Delhi         739800.0
# Mumbai        475100.0
# Unknown        14000.0
# Name: Sales, dtype: float64

# %% [markdown]
# ## Question - 7 Payment Method

# %%
# kitni sales kis payment method se hue hai ?
df.groupby('Payment_Method')["Sales"].sum()
# Out:
# Payment_Method
# Cash           1151300.0
# Credit Card     911900.0
# Debit Card      759700.0
# UPI            1077500.0
# Unknown           6600.0
# Name: Sales, dtype: float64

# %%
df.groupby('Product')["Quantity"].sum().sort_values(ascending = False)
# Out:
# Product
# Backpack      76
# Keyboard      61
# Shoes         53
# Mouse         50
# Monitor       41
# Laptop        41
# Headphones    33
# Phone         19
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Time Analysis

# %%
# question - Kis month me sabse zyada sales hue hai 
df['Month'] =df['Order_Date'].dt.to_period('M')

# %%
df.head()
# Out:
#    Order_ID Order_Date   Product     Category  Quantity   Price    City  \
# 0      1001 2025-06-29     Shoes      Fashion         1  3500.0  Mumbai
# 1      1002 2025-01-21     Mouse  Accessories         3   900.0   Delhi
# 2      1003 2025-03-16     Shoes      Fashion         3  3500.0    Pune
# 3      1004 2025-06-01  Backpack      Fashion         3  2200.0    Pune
# 4      1005 2025-06-07  Backpack      Fashion         2  2200.0   Delhi
#
#   Payment_Method    Sales    Month
# 0           Cash   3500.0  2025-06
# 1     Debit Card   2700.0  2025-01
# 2           Cash  10500.0  2025-03
# 3    Credit Card   6600.0  2025-06
# 4           Cash   4400.0  2025-06

# %%
df.groupby('Month')["Sales"].sum().sort_values(ascending = False)
# Out:
# Month
# 2025-01    1155700.0
# 2025-05    1040500.0
# 2025-04     685500.0
# 2025-06     549300.0
# 2025-03     261400.0
# 2025-02     214600.0
# Freq: M, Name: Sales, dtype: float64

# %% [markdown]
# ##  Monthly Sales Trend

# %%
## Sales Time ke sath kaise change ho rahi hai
monthly_sales = df.groupby('Month')["Sales"].sum()
plt.figure(figsize =(10,5))
plt.plot(monthly_sales.index.astype(str),monthly_sales.values,marker = 'o')

plt.title('Monthly Sales Trend')
plt.xlabel('Months')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ##  Category Sales ka Bar Chart

# %%
category_sales = df.groupby('Category')["Sales"].sum()
plt.figure(figsize =(8,5))

plt.bar(category_sales.index,category_sales.values)
plt.title('Sales By Category')
plt.xlabel('Category')
plt.ylabel('Total_Sales')

plt.show()

# %% [markdown]
# ## Product Sales

# %%
product_sales = df.groupby('Product')["Sales"].sum()
plt.figure(figsize =(10,5))
plt.bar(product_sales.index,product_sales.values)

plt.title('Sales By Product')
plt.xlabel('Product')
plt.ylabel('Total_Sales')

plt.show()

# %% [markdown]
# ##  Use Seaborn Library

# %%
# Konsa payment method ka kitna usage hai

sns.countplot(data =df ,x= 'Payment_Method')
plt.title('Orders By Payment Method')
# Out:
# Text(0.5, 1.0, 'Orders By Payment Method')

# %% [markdown]
# ##  Sales Distribution

# %%
sns.histplot(data =df ,x ='Sales')
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
# Kya dataset mein unusually  high/low Sales Values hain?
#Boxplot
sns.boxplot(data =df ,y ='Sales')
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# ##  Key Insights
#
# 1. Total sales were ₹39.07 lakh.
# 2. Electronics generated the highest revenue among categories.
# 3. Laptop generated the highest product-level revenue.
# 4. Backpack had the highest quantity sold.
# 5. Indore generated the highest sales among cities.
# 6. January had the highest monthly sales in this dataset.
# 7. Sales distribution is right-skewed, with some high-value orders.

# %% [markdown]
# ## Conclusion
#
# The analysis shows that Electronics is the major revenue-generating
# category, while Laptop contributes the highest product-level revenue.
# Although Backpack has the highest number of units sold, its revenue is
# much lower because of its lower price.
#
# Sales vary considerably across months and cities. The business could
# further investigate high-value products, monthly sales fluctuations,
# and city-level performance.
